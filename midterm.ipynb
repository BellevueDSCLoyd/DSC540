# %% [markdown]
# <h1><center>Austin Animal Center Shelter Outcomes Data</center></h1>
# <h3><center>Sam Loyd</center></h3>
# <h3><center>DSC 540</center></h3>
# <h3><center>January 2020</center></h3>

# %% [markdown]
# This data can be found at
#
# https://www.kaggle.com/aaronschlegel/austin-animal-center-shelter-outcomes-and
#
# Context quoted from site above:
#
# ##### The Austin Animal Center is the largest no-kill animal shelter in the United States that provides care and shelter to over 18,000 animals each year and is involved in a range of county, city, and state-wide initiatives for the protection and care of abandoned, at-risk, and surrendered animals.
#
# ##### As part of the City of Austin Open Data Initiative, the Austin Animal Center makes available its collected dataset that contains statistics and outcomes of animals entering the Austin Animal Services system (Austin Animal Shelter, 2017).
#
# The following list of variables was taken from sparsely populated codebook at site above.
#
# ##### 37 Variables:
# age_upon_outcome Age of the animal at the time at which it left the shelter.
# animal_id
# animal_type Cat, dog, or other (including at least one bat!).
# breed Animal breed. Many animals are generic mixed-breeds, e.g. "Long-haired mix".
# color Color of the animal's fur, if it has fur.
# date_of_birth
# datetime Timestamp of outcome
# monthyear
# name
# outcome_subtype
# outcome_type Ultimate outcome for this animal. Possible entries include transferred, [mercy] euthanized, adopted.
# sex_upon_outcome
# count
# sex
# Spay/Neuter
# Periods
# Period Range
# outcome_age_(days)
# outcome_age_(years)
# Cat/Kitten (outcome)
# sex_age_outcome
# age_group
# dob_year
# dob_month
# dob_monthyear
# outcome_month
# outcome_year
# outcome_weekday
# outcome_hour
# breed1
# breed2
# cfa_breed
# domestic_breed
# coat_pattern
# color1
# color2
# coat

# %% [markdown]
# ### Replace headers (Data Wrangling with Python pg. 154 – 163)

# %%
# Required modules
import pprint
import numpy as np
import datetime
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re
from termcolor import colored

# %%
# The data set that I chose came from Kaggle at the above address.
# The data set did not contain a matching header file so I manually created one from the 
# information that I had.

from csv import DictReader

data_rdr = DictReader(open('aac_shelter_cat_outcome_eng.csv', 'rt'))
header_rdr = DictReader(open('aac_replacement_headers.csv', 'rt'))

data_rows = [d for d in data_rdr]
header_rows = [h for h in header_rdr]

# %% [markdown]
# ##### Basic look at the data

# %%
# Count rows
print(len(data_rows))
# Out:
# 29421

# %%
# Count headers from generated file.
print(len(header_rows))
# Out:
# 37

# %%
# View data_rows
data_rows
# Out:
# [OrderedDict([('age_upon_outcome', '2 weeks'),
#               ('animal_id', 'A684346'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'orange'),
#               ('date_of_birth', '2014-07-07 00:00:00'),
#               ('datetime', '2014-07-22 16:04:00'),
#               ('monthyear', '2014-07-22T16:04:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '2'),
#               ('Period Range', '7'),
#               ('outcome_age_(days)', '14'),
#               ('outcome_age_(years)', '0.038356164383561646'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '7'),
#               ('dob_monthyear', '2014-07'),
#               ('outcome_month', '7'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Tuesday'),
#               ('outcome_hour', '16'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'orange'),
#               ('color2', ''),
#               ('coat', 'orange')]),
#  OrderedDict([('age_upon_outcome', '1 month'),
#               ('animal_id', 'A685067'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'blue /white'),
#               ('date_of_birth', '2014-06-16 00:00:00'),
#               ('datetime', '2014-08-14 18:45:00'),
#               ('monthyear', '2014-08-14T18:45:00'),
#               ('name', 'Lucy'),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '1'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '30'),
#               ('outcome_age_(years)', '0.0821917808219178'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '6'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '18'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'blue '),
#               ('color2', 'white'),
#               ('coat', 'blue ')]),
#  OrderedDict([('age_upon_outcome', '3 months'),
#               ('animal_id', 'A678580'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'white/black'),
#               ('date_of_birth', '2014-03-26 00:00:00'),
#               ('datetime', '2014-06-29 17:45:00'),
#               ('monthyear', '2014-06-29T17:45:00'),
#               ('name', '*Frida'),
#               ('outcome_subtype', 'Offsite'),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '3'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '90'),
#               ('outcome_age_(years)', '0.2465753424657534'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Spayed Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '3'),
#               ('dob_monthyear', '2014-06'),
#               ('outcome_month', '6'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Sunday'),
#               ('outcome_hour', '17'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'white'),
#               ('color2', 'black'),
#               ('coat', 'white')]),
#  OrderedDict([('age_upon_outcome', '1 year'),
#               ('animal_id', 'A675405'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic mediumhair'),
#               ('color', 'black/white'),
#               ('date_of_birth', '2013-03-27 00:00:00'),
#               ('datetime', '2014-03-28 14:55:00'),
#               ('monthyear', '2014-03-28T14:55:00'),
#               ('name', 'Stella Luna'),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Return to Owner'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '1'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '365'),
#               ('outcome_age_(years)', '1.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Spayed Female Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '3'),
#               ('dob_monthyear', '2014-03'),
#               ('outcome_month', '3'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Friday'),
#               ('outcome_hour', '14'),
#               ('breed1', 'domestic mediumhair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', 'white'),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '3 weeks'),
#               ('animal_id', 'A670420'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black/white'),
#               ('date_of_birth', '2013-12-16 00:00:00'),
#               ('datetime', '2014-01-09 19:29:00'),
#               ('monthyear', '2014-01-09T19:29:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '3'),
#               ('Period Range', '7'),
#               ('outcome_age_(days)', '21'),
#               ('outcome_age_(years)', '0.057534246575342465'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '12'),
#               ('dob_monthyear', '2014-01'),
#               ('outcome_month', '1'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '19'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', 'white'),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '2 months'),
#               ('animal_id', 'A684460'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'brown'),
#               ('date_of_birth', '2014-06-02 00:00:00'),
#               ('datetime', '2014-08-13 15:04:00'),
#               ('monthyear', '2014-08-13T15:04:00'),
#               ('name', 'Elsa'),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '60'),
#               ('outcome_age_(years)', '0.1643835616438356'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Spayed Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '6'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Wednesday'),
#               ('outcome_hour', '15'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'brown'),
#               ('color2', ''),
#               ('coat', 'brown')]),
#  OrderedDict([('age_upon_outcome', '8 months'),
#               ('animal_id', 'A673952'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'brown /white'),
#               ('date_of_birth', '2013-07-05 00:00:00'),
#               ('datetime', '2014-03-06 14:29:00'),
#               ('monthyear', '2014-03-06T14:29:00'),
#               ('name', ''),
#               ('outcome_subtype', 'SCRP'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Unknown'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '8'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '240'),
#               ('outcome_age_(years)', '0.6575342465753424'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Unknown Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '7'),
#               ('dob_monthyear', '2014-03'),
#               ('outcome_month', '3'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '14'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'brown '),
#               ('color2', 'white'),
#               ('coat', 'brown ')]),
#  OrderedDict([('age_upon_outcome', '5 months'),
#               ('animal_id', 'A686497'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black'),
#               ('date_of_birth', '2014-03-22 00:00:00'),
#               ('datetime', '2014-08-31 15:45:00'),
#               ('monthyear', '2014-08-31T15:45:00'),
#               ('name', 'Chester'),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '5'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '150'),
#               ('outcome_age_(years)', '0.410958904109589'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Neutered Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '3'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Sunday'),
#               ('outcome_hour', '15'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'black'),
#               ('color2', ''),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '2 months'),
#               ('animal_id', 'A687965'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'orange'),
#               ('date_of_birth', '2014-08-03 00:00:00'),
#               ('datetime', '2014-10-31 18:29:00'),
#               ('monthyear', '2014-10-31T18:29:00'),
#               ('name', '*Oliver'),
#               ('outcome_subtype', 'Foster'),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '60'),
#               ('outcome_age_(years)', '0.1643835616438356'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Neutered Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '8'),
#               ('dob_monthyear', '2014-10'),
#               ('outcome_month', '10'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Friday'),
#               ('outcome_hour', '18'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'orange'),
#               ('color2', ''),
#               ('coat', 'orange')]),
#  OrderedDict([('age_upon_outcome', '1 year'),
#               ('animal_id', 'A668547'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic mediumhair'),
#               ('color', 'black/white'),
#               ('date_of_birth', '2012-12-04 00:00:00'),
#               ('datetime', '2013-12-16 13:59:00'),
#               ('monthyear', '2013-12-16T13:59:00'),
#               ('name', '*Preston'),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '1'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '365'),
#               ('outcome_age_(years)', '1.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Neutered Male Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2012'),
#               ('dob_month', '12'),
#               ('dob_monthyear', '2013-12'),
#               ('outcome_month', '12'),
#               ('outcome_year', '2013'),
#               ('outcome_weekday', 'Monday'),
#               ('outcome_hour', '13'),
#               ('breed1', 'domestic mediumhair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', 'white'),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '2 months'),
#               ('animal_id', 'A682393'),
#               ('animal_type', 'Cat'),
#               ('breed', 'siamese'),
#               ('color', 'seal'),
#               ('date_of_birth', '2014-04-27 00:00:00'),
#               ('datetime', '2014-07-03 12:12:00'),
#               ('monthyear', '2014-07-03T12:12:00'),
#               ('name', '*Bumble'),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '2'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '60'),
#               ('outcome_age_(years)', '0.1643835616438356'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '4'),
#               ('dob_monthyear', '2014-07'),
#               ('outcome_month', '7'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '12'),
#               ('breed1', 'siamese'),
#               ('breed2', ''),
#               ('cfa_breed', 'True'),
#               ('domestic_breed', 'False'),
#               ('coat_pattern', 'point'),
#               ('color1', 'seal'),
#               ('color2', ''),
#               ('coat', 'seal')]),
#  OrderedDict([('age_upon_outcome', '2 weeks'),
#               ('animal_id', 'A681039'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black'),
#               ('date_of_birth', '2014-05-27 00:00:00'),
#               ('datetime', '2014-06-11 17:11:00'),
#               ('monthyear', '2014-06-11T17:11:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Unknown'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '7'),
#               ('outcome_age_(days)', '14'),
#               ('outcome_age_(years)', '0.038356164383561646'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Unknown Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '5'),
#               ('dob_monthyear', '2014-06'),
#               ('outcome_month', '6'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Wednesday'),
#               ('outcome_hour', '17'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', ''),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '2 months'),
#               ('animal_id', 'A682532'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', ''),
#               ('date_of_birth', '2014-04-14 00:00:00'),
#               ('datetime', '2014-07-03 17:01:00'),
#               ('monthyear', '2014-07-03T17:01:00'),
#               ('name', ''),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '60'),
#               ('outcome_age_(years)', '0.1643835616438356'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Spayed Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '4'),
#               ('dob_monthyear', '2014-07'),
#               ('outcome_month', '7'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '17'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'torbie'),
#               ('color1', 'Breed Specific'),
#               ('color2', ''),
#               ('coat', 'torbie')]),
#  OrderedDict([('age_upon_outcome', '3 months'),
#               ('animal_id', 'A683779'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black'),
#               ('date_of_birth', '2014-04-15 00:00:00'),
#               ('datetime', '2014-07-19 17:36:00'),
#               ('monthyear', '2014-07-19T17:36:00'),
#               ('name', ''),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '3'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '90'),
#               ('outcome_age_(years)', '0.2465753424657534'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Spayed Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '4'),
#               ('dob_monthyear', '2014-07'),
#               ('outcome_month', '7'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '17'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', ''),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '3 weeks'),
#               ('animal_id', 'A686829'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black'),
#               ('date_of_birth', '2014-08-05 00:00:00'),
#               ('datetime', '2014-08-27 16:27:00'),
#               ('monthyear', '2014-08-27T16:27:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '3'),
#               ('Period Range', '7'),
#               ('outcome_age_(days)', '21'),
#               ('outcome_age_(years)', '0.057534246575342465'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '8'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Wednesday'),
#               ('outcome_hour', '16'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', ''),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '3 years'),
#               ('animal_id', 'A617061'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic mediumhair'),
#               ('color', 'orange'),
#               ('date_of_birth', '2011-08-02 00:00:00'),
#               ('datetime', '2014-09-04 09:57:00'),
#               ('monthyear', '2014-09-04T09:57:00'),
#               ('name', 'Pumpkin'),
#               ('outcome_subtype', 'In Kennel'),
#               ('outcome_type', 'Died'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '3'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '1095'),
#               ('outcome_age_(years)', '3.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Neutered Male Cat'),
#               ('age_group', '(2.2, 4.4]'),
#               ('dob_year', '2011'),
#               ('dob_month', '8'),
#               ('dob_monthyear', '2014-09'),
#               ('outcome_month', '9'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '9'),
#               ('breed1', 'domestic mediumhair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'orange'),
#               ('color2', ''),
#               ('coat', 'orange')]),
#  OrderedDict([('age_upon_outcome', '4 years'),
#               ('animal_id', 'A682085'),
#               ('animal_type', 'Cat'),
#               ('breed', 'russian blue'),
#               ('color', 'blue'),
#               ('date_of_birth', '2010-06-24 00:00:00'),
#               ('datetime', '2014-07-12 15:00:00'),
#               ('monthyear', '2014-07-12T15:00:00'),
#               ('name', 'Winnie'),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '4'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '1460'),
#               ('outcome_age_(years)', '4.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Spayed Female Cat'),
#               ('age_group', '(2.2, 4.4]'),
#               ('dob_year', '2010'),
#               ('dob_month', '6'),
#               ('dob_monthyear', '2014-07'),
#               ('outcome_month', '7'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '15'),
#               ('breed1', 'russian blue'),
#               ('breed2', ''),
#               ('cfa_breed', 'True'),
#               ('domestic_breed', 'False'),
#               ('coat_pattern', ''),
#               ('color1', 'blue'),
#               ('color2', ''),
#               ('coat', 'blue')]),
#  OrderedDict([('age_upon_outcome', '2 years'),
#               ('animal_id', 'A692877'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'cream /white'),
#               ('date_of_birth', '2012-11-26 00:00:00'),
#               ('datetime', '2014-12-09 15:18:00'),
#               ('monthyear', '2014-12-09T15:18:00'),
#               ('name', 'Snowflake'),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '730'),
#               ('outcome_age_(years)', '2.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Neutered Male Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2012'),
#               ('dob_month', '11'),
#               ('dob_monthyear', '2014-12'),
#               ('outcome_month', '12'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Tuesday'),
#               ('outcome_hour', '15'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'cream '),
#               ('color2', 'white'),
#               ('coat', 'cream ')]),
#  OrderedDict([('age_upon_outcome', '7 years'),
#               ('animal_id', 'A683856'),
#               ('animal_type', 'Cat'),
#               ('breed', 'russian blue'),
#               ('color', 'blue'),
#               ('date_of_birth', '2007-07-16 00:00:00'),
#               ('datetime', '2014-08-12 15:42:00'),
#               ('monthyear', '2014-08-12T15:42:00'),
#               ('name', 'Smoke'),
#               ('outcome_subtype', 'Foster'),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '7'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '2555'),
#               ('outcome_age_(years)', '7.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Neutered Male Cat'),
#               ('age_group', '(6.6, 8.8]'),
#               ('dob_year', '2007'),
#               ('dob_month', '7'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Tuesday'),
#               ('outcome_hour', '15'),
#               ('breed1', 'russian blue'),
#               ('breed2', ''),
#               ('cfa_breed', 'True'),
#               ('domestic_breed', 'False'),
#               ('coat_pattern', ''),
#               ('color1', 'blue'),
#               ('color2', ''),
#               ('coat', 'blue')]),
#  OrderedDict([('age_upon_outcome', '1 month'),
#               ('animal_id', 'A683517'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', ''),
#               ('date_of_birth', '2014-06-05 00:00:00'),
#               ('datetime', '2014-07-19 13:08:00'),
#               ('monthyear', '2014-07-19T13:08:00'),
#               ('name', '*Dora'),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '1'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '30'),
#               ('outcome_age_(years)', '0.0821917808219178'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '6'),
#               ('dob_monthyear', '2014-07'),
#               ('outcome_month', '7'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '13'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'calico'),
#               ('color1', 'Breed Specific'),
#               ('color2', ''),
#               ('coat', 'calico')]),
#  OrderedDict([('age_upon_outcome', '1 year'),
#               ('animal_id', 'A688811'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic mediumhair'),
#               ('color', 'brown'),
#               ('date_of_birth', '2013-09-24 00:00:00'),
#               ('datetime', '2014-09-25 09:00:00'),
#               ('monthyear', '2014-09-25T09:00:00'),
#               ('name', ''),
#               ('outcome_subtype', 'SCRP'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '1'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '365'),
#               ('outcome_age_(years)', '1.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Intact Female Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '9'),
#               ('dob_monthyear', '2014-09'),
#               ('outcome_month', '9'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '9'),
#               ('breed1', 'domestic mediumhair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'brown'),
#               ('color2', ''),
#               ('coat', 'brown')]),
#  OrderedDict([('age_upon_outcome', '2 years'),
#               ('animal_id', 'A680225'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', ''),
#               ('date_of_birth', '2012-05-31 00:00:00'),
#               ('datetime', '2014-06-01 17:15:00'),
#               ('monthyear', '2014-06-01T17:15:00'),
#               ('name', ''),
#               ('outcome_subtype', 'SCRP'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '2'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '730'),
#               ('outcome_age_(years)', '2.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Intact Female Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2012'),
#               ('dob_month', '5'),
#               ('dob_monthyear', '2014-06'),
#               ('outcome_month', '6'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Sunday'),
#               ('outcome_hour', '17'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'calico'),
#               ('color1', 'Breed Specific'),
#               ('color2', ''),
#               ('coat', 'calico')]),
#  OrderedDict([('age_upon_outcome', '2 months'),
#               ('animal_id', 'A662912'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'chocolate'),
#               ('date_of_birth', '2013-08-10 00:00:00'),
#               ('datetime', '2013-10-20 12:21:00'),
#               ('monthyear', '2013-10-20T12:21:00'),
#               ('name', '*Cosmo'),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '60'),
#               ('outcome_age_(years)', '0.1643835616438356'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Neutered Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '8'),
#               ('dob_monthyear', '2013-10'),
#               ('outcome_month', '10'),
#               ('outcome_year', '2013'),
#               ('outcome_weekday', 'Sunday'),
#               ('outcome_hour', '12'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'chocolate'),
#               ('color2', ''),
#               ('coat', 'chocolate')]),
#  OrderedDict([('age_upon_outcome', '4 weeks'),
#               ('animal_id', 'A677218'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'brown'),
#               ('date_of_birth', '2014-03-21 00:00:00'),
#               ('datetime', '2014-04-21 18:04:00'),
#               ('monthyear', '2014-04-21T18:04:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '4'),
#               ('Period Range', '7'),
#               ('outcome_age_(days)', '28'),
#               ('outcome_age_(years)', '0.07671232876712329'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '3'),
#               ('dob_monthyear', '2014-04'),
#               ('outcome_month', '4'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Monday'),
#               ('outcome_hour', '18'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'brown'),
#               ('color2', ''),
#               ('coat', 'brown')]),
#  OrderedDict([('age_upon_outcome', '3 months'),
#               ('animal_id', 'A691708'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'brown /white'),
#               ('date_of_birth', '2014-08-01 00:00:00'),
#               ('datetime', '2014-11-09 09:00:00'),
#               ('monthyear', '2014-11-09T09:00:00'),
#               ('name', ''),
#               ('outcome_subtype', 'SCRP'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '3'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '90'),
#               ('outcome_age_(years)', '0.2465753424657534'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '8'),
#               ('dob_monthyear', '2014-11'),
#               ('outcome_month', '11'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Sunday'),
#               ('outcome_hour', '9'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'brown '),
#               ('color2', 'white'),
#               ('coat', 'brown ')]),
#  OrderedDict([('age_upon_outcome', '1 year'),
#               ('animal_id', 'A670066'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', ''),
#               ('date_of_birth', '2013-01-01 00:00:00'),
#               ('datetime', '2014-01-12 12:06:00'),
#               ('monthyear', '2014-01-12T12:06:00'),
#               ('name', '*Sophie'),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '1'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '365'),
#               ('outcome_age_(years)', '1.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Spayed Female Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '1'),
#               ('dob_monthyear', '2014-01'),
#               ('outcome_month', '1'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Sunday'),
#               ('outcome_hour', '12'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'torbie'),
#               ('color1', 'Breed Specific'),
#               ('color2', ''),
#               ('coat', 'torbie')]),
#  OrderedDict([('age_upon_outcome', '2 months'),
#               ('animal_id', 'A667511'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic mediumhair'),
#               ('color', 'brown'),
#               ('date_of_birth', '2013-09-04 00:00:00'),
#               ('datetime', '2013-11-19 13:43:00'),
#               ('monthyear', '2013-11-19T13:43:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Suffering'),
#               ('outcome_type', 'Euthanasia'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '2'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '60'),
#               ('outcome_age_(years)', '0.1643835616438356'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '9'),
#               ('dob_monthyear', '2013-11'),
#               ('outcome_month', '11'),
#               ('outcome_year', '2013'),
#               ('outcome_weekday', 'Tuesday'),
#               ('outcome_hour', '13'),
#               ('breed1', 'domestic mediumhair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'brown'),
#               ('color2', ''),
#               ('coat', 'brown')]),
#  OrderedDict([('age_upon_outcome', '6 years'),
#               ('animal_id', 'A670656'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'blue /white'),
#               ('date_of_birth', '2008-01-11 00:00:00'),
#               ('datetime', '2014-01-17 12:33:00'),
#               ('monthyear', '2014-01-17T12:33:00'),
#               ('name', 'Mischief'),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Return to Owner'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '6'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '2190'),
#               ('outcome_age_(years)', '6.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Neutered Male Cat'),
#               ('age_group', '(4.4, 6.6]'),
#               ('dob_year', '2008'),
#               ('dob_month', '1'),
#               ('dob_monthyear', '2014-01'),
#               ('outcome_month', '1'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Friday'),
#               ('outcome_hour', '12'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'blue '),
#               ('color2', 'white'),
#               ('coat', 'blue ')]),
#  OrderedDict([('age_upon_outcome', '2 years'),
#               ('animal_id', 'A688674'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black/white'),
#               ('date_of_birth', '2012-09-22 00:00:00'),
#               ('datetime', '2014-09-23 09:00:00'),
#               ('monthyear', '2014-09-23T09:00:00'),
#               ('name', ''),
#               ('outcome_subtype', 'SCRP'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Neutered Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '730'),
#               ('outcome_age_(years)', '2.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Neutered Male Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2012'),
#               ('dob_month', '9'),
#               ('dob_monthyear', '2014-09'),
#               ('outcome_month', '9'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Tuesday'),
#               ('outcome_hour', '9'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', 'white'),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '2 weeks'),
#               ('animal_id', 'A677633'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black/white'),
#               ('date_of_birth', '2014-04-12 00:00:00'),
#               ('datetime', '2014-04-27 15:35:00'),
#               ('monthyear', '2014-04-27T15:35:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Suffering'),
#               ('outcome_type', 'Euthanasia'),
#               ('sex_upon_outcome', 'Unknown'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '7'),
#               ('outcome_age_(days)', '14'),
#               ('outcome_age_(years)', '0.038356164383561646'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Unknown Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '4'),
#               ('dob_monthyear', '2014-04'),
#               ('outcome_month', '4'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Sunday'),
#               ('outcome_hour', '15'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', 'white'),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '3 weeks'),
#               ('animal_id', 'A688532'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'orange'),
#               ('date_of_birth', '2014-08-29 00:00:00'),
#               ('datetime', '2014-09-20 18:26:00'),
#               ('monthyear', '2014-09-20T18:26:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '3'),
#               ('Period Range', '7'),
#               ('outcome_age_(days)', '21'),
#               ('outcome_age_(years)', '0.057534246575342465'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '8'),
#               ('dob_monthyear', '2014-09'),
#               ('outcome_month', '9'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '18'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'orange'),
#               ('color2', ''),
#               ('coat', 'orange')]),
#  OrderedDict([('age_upon_outcome', '2 months'),
#               ('animal_id', 'A687769'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'brown'),
#               ('date_of_birth', '2014-09-09 00:00:00'),
#               ('datetime', '2014-11-22 15:08:00'),
#               ('monthyear', '2014-11-22T15:08:00'),
# ...
#               ('dob_year', '2011'),
#               ('dob_month', '9'),
#               ('dob_monthyear', '2014-09'),
#               ('outcome_month', '9'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '17'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'orange'),
#               ('color2', ''),
#               ('coat', 'orange')]),
#  OrderedDict([('age_upon_outcome', '5 years'),
#               ('animal_id', 'A674206'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic longhair'),
#               ('color', '/white'),
#               ('date_of_birth', '2009-03-09 00:00:00'),
#               ('datetime', '2014-03-22 12:25:00'),
#               ('monthyear', '2014-03-22T12:25:00'),
#               ('name', 'Tiger'),
#               ('outcome_subtype', ''),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '5'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '1825'),
#               ('outcome_age_(years)', '5.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Spayed Female Cat'),
#               ('age_group', '(4.4, 6.6]'),
#               ('dob_year', '2009'),
#               ('dob_month', '3'),
#               ('dob_monthyear', '2014-03'),
#               ('outcome_month', '3'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '12'),
#               ('breed1', 'domestic longhair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'torbie'),
#               ('color1', 'Breed Specific'),
#               ('color2', 'white'),
#               ('coat', 'torbie')]),
#  OrderedDict([('age_upon_outcome', '3 years'),
#               ('animal_id', 'A685352'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'brown /white'),
#               ('date_of_birth', '2011-08-06 00:00:00'),
#               ('datetime', '2014-08-07 13:23:00'),
#               ('monthyear', '2014-08-07T13:23:00'),
#               ('name', '*Babs'),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '3'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '1095'),
#               ('outcome_age_(years)', '3.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Intact Female Cat'),
#               ('age_group', '(2.2, 4.4]'),
#               ('dob_year', '2011'),
#               ('dob_month', '8'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Thursday'),
#               ('outcome_hour', '13'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'brown '),
#               ('color2', 'white'),
#               ('coat', 'brown ')]),
#  OrderedDict([('age_upon_outcome', '1 month'),
#               ('animal_id', 'A681958'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black/white'),
#               ('date_of_birth', '2014-05-15 00:00:00'),
#               ('datetime', '2014-07-12 11:21:00'),
#               ('monthyear', '2014-07-12T11:21:00'),
#               ('name', '*Nelda'),
#               ('outcome_subtype', 'Foster'),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '1'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '30'),
#               ('outcome_age_(years)', '0.0821917808219178'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Spayed Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '5'),
#               ('dob_monthyear', '2014-07'),
#               ('outcome_month', '7'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '11'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', 'white'),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '3 months'),
#               ('animal_id', 'A686521'),
#               ('animal_type', 'Cat'),
#               ('breed', 'siamese'),
#               ('color', 'lilac'),
#               ('date_of_birth', '2014-05-23 00:00:00'),
#               ('datetime', '2014-08-24 09:00:00'),
#               ('monthyear', '2014-08-24T09:00:00'),
#               ('name', ''),
#               ('outcome_subtype', 'SCRP'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '3'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '90'),
#               ('outcome_age_(years)', '0.2465753424657534'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '5'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Sunday'),
#               ('outcome_hour', '9'),
#               ('breed1', 'siamese'),
#               ('breed2', ''),
#               ('cfa_breed', 'True'),
#               ('domestic_breed', 'False'),
#               ('coat_pattern', 'point'),
#               ('color1', 'lilac'),
#               ('color2', ''),
#               ('coat', 'lilac')]),
#  OrderedDict([('age_upon_outcome', '3 weeks'),
#               ('animal_id', 'A686741'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'cream /white'),
#               ('date_of_birth', '2014-08-04 00:00:00'),
#               ('datetime', '2014-08-26 14:00:00'),
#               ('monthyear', '2014-08-26T14:00:00'),
#               ('name', ''),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '3'),
#               ('Period Range', '7'),
#               ('outcome_age_(days)', '21'),
#               ('outcome_age_(years)', '0.057534246575342465'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Intact Male Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '8'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Tuesday'),
#               ('outcome_hour', '14'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'cream '),
#               ('color2', 'white'),
#               ('coat', 'cream ')]),
#  OrderedDict([('age_upon_outcome', '1 year'),
#               ('animal_id', 'A674735'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', '/orange'),
#               ('date_of_birth', '2013-03-17 00:00:00'),
#               ('datetime', '2014-05-07 14:44:00'),
#               ('monthyear', '2014-05-07T14:44:00'),
#               ('name', '*Dahlia'),
#               ('outcome_subtype', 'Partner'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '1'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '365'),
#               ('outcome_age_(years)', '1.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Spayed Female Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '3'),
#               ('dob_monthyear', '2014-05'),
#               ('outcome_month', '5'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Wednesday'),
#               ('outcome_hour', '14'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tortie'),
#               ('color1', 'Breed Specific'),
#               ('color2', 'orange'),
#               ('coat', 'tortie')]),
#  OrderedDict([('age_upon_outcome', '1 year'),
#               ('animal_id', 'A671200'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black/white'),
#               ('date_of_birth', '2013-01-21 00:00:00'),
#               ('datetime', '2014-01-22 15:11:00'),
#               ('monthyear', '2014-01-22T15:11:00'),
#               ('name', ''),
#               ('outcome_subtype', 'SCRP'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Intact Male'),
#               ('count', '1'),
#               ('sex', 'Male'),
#               ('Spay/Neuter', 'No'),
#               ('Periods', '1'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '365'),
#               ('outcome_age_(years)', '1.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Intact Male Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '1'),
#               ('dob_monthyear', '2014-01'),
#               ('outcome_month', '1'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Wednesday'),
#               ('outcome_hour', '15'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', 'white'),
#               ('coat', 'black')]),
#  OrderedDict([('age_upon_outcome', '1 year'),
#               ('animal_id', 'A673604'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'orange'),
#               ('date_of_birth', '2013-02-27 00:00:00'),
#               ('datetime', '2014-03-01 13:59:00'),
#               ('monthyear', '2014-03-01T13:59:00'),
#               ('name', ''),
#               ('outcome_subtype', 'SCRP'),
#               ('outcome_type', 'Transfer'),
#               ('sex_upon_outcome', 'Unknown'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '1'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '365'),
#               ('outcome_age_(years)', '1.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Unknown Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '2'),
#               ('dob_monthyear', '2014-03'),
#               ('outcome_month', '3'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '13'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'tabby'),
#               ('color1', 'orange'),
#               ('color2', ''),
#               ('coat', 'orange')]),
#  OrderedDict([('age_upon_outcome', '1 year'),
#               ('animal_id', 'A680192'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black /white'),
#               ('date_of_birth', '2013-05-30 00:00:00'),
#               ('datetime', '2014-08-23 12:59:00'),
#               ('monthyear', '2014-08-23T12:59:00'),
#               ('name', '*Tootsie'),
#               ('outcome_subtype', 'Foster'),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '1'),
#               ('Period Range', '365'),
#               ('outcome_age_(days)', '365'),
#               ('outcome_age_(years)', '1.0'),
#               ('Cat/Kitten (outcome)', 'Cat'),
#               ('sex_age_outcome', 'Spayed Female Cat'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2013'),
#               ('dob_month', '5'),
#               ('dob_monthyear', '2014-08'),
#               ('outcome_month', '8'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '12'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', 'smoke'),
#               ('color1', 'black '),
#               ('color2', 'white'),
#               ('coat', 'black ')]),
#  OrderedDict([('age_upon_outcome', '2 months'),
#               ('animal_id', 'A679550'),
#               ('animal_type', 'Cat'),
#               ('breed', 'domestic shorthair'),
#               ('color', 'black/white'),
#               ('date_of_birth', '2014-04-23 00:00:00'),
#               ('datetime', '2014-07-12 17:42:00'),
#               ('monthyear', '2014-07-12T17:42:00'),
#               ('name', '*Susie'),
#               ('outcome_subtype', 'Foster'),
#               ('outcome_type', 'Adoption'),
#               ('sex_upon_outcome', 'Spayed Female'),
#               ('count', '1'),
#               ('sex', 'Female'),
#               ('Spay/Neuter', 'Yes'),
#               ('Periods', '2'),
#               ('Period Range', '30'),
#               ('outcome_age_(days)', '60'),
#               ('outcome_age_(years)', '0.1643835616438356'),
#               ('Cat/Kitten (outcome)', 'Kitten'),
#               ('sex_age_outcome', 'Spayed Female Kitten'),
#               ('age_group', '(-0.022, 2.2]'),
#               ('dob_year', '2014'),
#               ('dob_month', '4'),
#               ('dob_monthyear', '2014-07'),
#               ('outcome_month', '7'),
#               ('outcome_year', '2014'),
#               ('outcome_weekday', 'Saturday'),
#               ('outcome_hour', '17'),
#               ('breed1', 'domestic shorthair'),
#               ('breed2', ''),
#               ('cfa_breed', 'False'),
#               ('domestic_breed', 'True'),
#               ('coat_pattern', ''),
#               ('color1', 'black'),
#               ('color2', 'white'),
#               ('coat', 'black')]),
#  ...]

# %% [markdown]
# ##### Data that I generated in a csv file to create new headers from.

# %%
# View header_rows
header_rows
# Out:
# [OrderedDict([('Column', 'age_upon_outcome'),
#               ('Title', 'Outcome Age'),
#               ('Explanation', 'Age upon leaving shelter.')]),
#  OrderedDict([('Column', 'animal_id'),
#               ('Title', 'Animal ID'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'animal_type'),
#               ('Title', 'Animal Type'),
#               ('Explanation', 'Animal breed.  Many are generic.')]),
#  OrderedDict([('Column', 'breed'), ('Title', 'Breed'), ('Explanation', '')]),
#  OrderedDict([('Column', 'color'),
#               ('Title', 'Color'),
#               ('Explanation', "Color of Animal's fur if applicable.")]),
#  OrderedDict([('Column', 'date_of_birth'),
#               ('Title', 'Date Of Birth'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'datetime'),
#               ('Title', 'Outcome Age Timestamp'),
#               ('Explanation', 'TimeStamp of outcome.')]),
#  OrderedDict([('Column', 'monthyear'),
#               ('Title', 'Outcome Month-Year'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'name'), ('Title', 'Name'), ('Explanation', '')]),
#  OrderedDict([('Column', 'outcome_subtype'),
#               ('Title', 'Outcome Subtype'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'outcome_type'),
#               ('Title', 'Outcome Type'),
#               ('Explanation', 'Ultimate outcome for animal. ')]),
#  OrderedDict([('Column', 'sex_upon_outcome'),
#               ('Title', 'Outcome Sex'),
#               ('Explanation', 'Sex upon leaving shelter.')]),
#  OrderedDict([('Column', 'count'), ('Title', 'Count'), ('Explanation', '')]),
#  OrderedDict([('Column', 'sex'), ('Title', 'Sex'), ('Explanation', '')]),
#  OrderedDict([('Column', 'Spay/Neuter'),
#               ('Title', 'Spay-Neuter'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'Periods'),
#               ('Title', 'Periods'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'Period Range'),
#               ('Title', 'Period Range'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'outcome_age_(days)'),
#               ('Title', 'Outcome Age in Days'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'outcome_age_(years)'),
#               ('Title', 'Outcome Age in Years'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'Cat/Kitten (outcome)'),
#               ('Title', 'Outcome Cat-Kitten'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'sex_age_outcome'),
#               ('Title', 'Outcome Sex Age'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'age_group'),
#               ('Title', 'Age Group'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'dob_year'),
#               ('Title', 'DOB Year'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'dob_month'),
#               ('Title', 'DOB Month'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'dob_monthyear'),
#               ('Title', 'DOB Month-Year'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'outcome_month'),
#               ('Title', 'Exit Month'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'outcome_year'),
#               ('Title', 'Outcome Year'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'outcome_weekday'),
#               ('Title', 'Outcome Weekday'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'outcome_hour'),
#               ('Title', 'Outcome Hour'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'breed1'),
#               ('Title', 'Primary Breed'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'breed2'),
#               ('Title', 'Secondary Breed '),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'cfa_breed'),
#               ('Title', 'CFA Breed'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'domestic_breed'),
#               ('Title', 'Domestic Breed'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'coat_pattern'),
#               ('Title', 'Coat Pattern'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'color1'),
#               ('Title', 'Primary Color'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'color2'),
#               ('Title', 'Secondary Color'),
#               ('Explanation', '')]),
#  OrderedDict([('Column', 'coat'), ('Title', 'Coat'), ('Explanation', '')])]

# %% [markdown]
# ##### Header Replacement in a list of dictionaries.

# %%
# Run through list of data rows.  Match the columns value in header_rows to 
# actual column headers in data rows.  If matched replace the column header 
# from data rows with the matching title value and create a new list of dictionarires
# for further analysis.

new_list = []
for dict_data_rows in data_rows:
    new_row = {}
    for dictkey, dictval in dict_data_rows.items():
        for dict_header_rows in header_rows:

            # This is used to get a exact match as using column could allow for redundant matches. 
            check_val = dict_header_rows.get('Column')
            replace_val = dict_header_rows.get('Title')          
            if dictkey in check_val:
                new_row[replace_val] = dictval
                
    new_list.append(new_row)

# %%
# Show first value to illustrate new titles.
new_list[0]
# Out:
# {'Outcome Age': '2 weeks',
#  'Animal ID': 'A684346',
#  'Animal Type': 'Cat',
#  'Breed': 'domestic shorthair',
#  'Primary Breed': 'domestic shorthair',
#  'Secondary Breed ': '',
#  'CFA Breed': 'False',
#  'Domestic Breed': 'True',
#  'Color': 'orange',
#  'Primary Color': 'orange',
#  'Secondary Color': '',
#  'Date Of Birth': '2014-07-07 00:00:00',
#  'Outcome Age Timestamp': '2014-07-22 16:04:00',
#  'Outcome Month-Year': '2014-07-22T16:04:00',
#  'DOB Month-Year': '2014-07',
#  'Name': '',
#  'Outcome Subtype': 'Partner',
#  'Outcome Type': 'Transfer',
#  'Outcome Sex': 'Male',
#  'Count': '1',
#  'Sex': 'Male',
#  'Outcome Sex Age': 'Intact Male Kitten',
#  'Spay-Neuter': 'No',
#  'Periods': '2',
#  'Period Range': '7',
#  'Outcome Age in Days': '14',
#  'Outcome Age in Years': '0.038356164383561646',
#  'Outcome Cat-Kitten': 'Kitten',
#  'Age Group': '(-0.022, 2.2]',
#  'DOB Year': '2014',
#  'DOB Month': '7',
#  'Exit Month': '7',
#  'Outcome Year': '2014',
#  'Outcome Weekday': 'Tuesday',
#  'Outcome Hour': '16',
#  'Coat Pattern': 'orange',
#  'Coat': 'orange'}

# %% [markdown]
# ### Format Data to a Readable Format (Data Wrangling with Python pg. 164 – 168)

# %%
# Place in a human readable format showing first row 
print("Query from the first entry (row 0) in the data set:")
for dictkey, dictval in new_list[0].items():
    # Clean up a few values and illustrate date formatting 
    # Get rid of the T in the output
    if dictkey == "Outcome Month-Year":
        # DEBUG print(type(dictval))
        # Use substitution to remove the T
        fixdictval = re.sub("T", " ", dictval)
        # DEBUG print(fixdictval)
        dictval = datetime.datetime.strptime(fixdictval, '%Y-%m-%d %H:%M:%S')
    # Decimal is unnecessarily long
    elif dictkey == "Outcome Age in Years":
        # DEBUG print(type(dictval))
        floatdict = round(float(dictval),2)
        dictval = floatdict
    elif dictval.find('/') > 0 and dictval.find(':') > 0:
        dictval = datetime.datetime.strptime(dictval, '%Y-%m-%d %H:%M:%S')
    dictkey = dictkey + "?"
    # Change color to highlight answers.
    print('\n  Question: What is the','{}'.format(dictkey),'\n    Answer:' \
          ,colored('{}','red').format(dictval))
# Out:
# Query from the first entry (row 0) in the data set:
#
#   Question: What is the Outcome Age?
#     Answer: 2 weeks
#
#   Question: What is the Animal ID?
#     Answer: A684346
#
#   Question: What is the Animal Type?
#     Answer: Cat
#
#   Question: What is the Breed?
#     Answer: domestic shorthair
#
#   Question: What is the Primary Breed?
#     Answer: domestic shorthair
#
#   Question: What is the Secondary Breed ?
#     Answer:
#
#   Question: What is the CFA Breed?
#     Answer: False
#
#   Question: What is the Domestic Breed?
#     Answer: True
#
#   Question: What is the Color?
#     Answer: orange
#
#   Question: What is the Primary Color?
#     Answer: orange
#
#   Question: What is the Secondary Color?
#     Answer:
#
#   Question: What is the Date Of Birth?
#     Answer: 2014-07-07 00:00:00
#
#   Question: What is the Outcome Age Timestamp?
#     Answer: 2014-07-22 16:04:00
#
#   Question: What is the Outcome Month-Year?
#     Answer: 2014-07-22 16:04:00
#
#   Question: What is the DOB Month-Year?
#     Answer: 2014-07
#
#   Question: What is the Name?
#     Answer:
#
#   Question: What is the Outcome Subtype?
#     Answer: Partner
#
#   Question: What is the Outcome Type?
#     Answer: Transfer
#
#   Question: What is the Outcome Sex?
#     Answer: Male
#
#   Question: What is the Count?
#     Answer: 1
#
#   Question: What is the Sex?
#     Answer: Male
#
#   Question: What is the Outcome Sex Age?
#     Answer: Intact Male Kitten
#
#   Question: What is the Spay-Neuter?
#     Answer: No
#
#   Question: What is the Periods?
#     Answer: 2
#
#   Question: What is the Period Range?
#     Answer: 7
#
#   Question: What is the Outcome Age in Days?
#     Answer: 14
#
#   Question: What is the Outcome Age in Years?
#     Answer: 0.04
#
#   Question: What is the Outcome Cat-Kitten?
#     Answer: Kitten
#
#   Question: What is the Age Group?
#     Answer: (-0.022, 2.2]
#
#   Question: What is the DOB Year?
#     Answer: 2014
#
#   Question: What is the DOB Month?
#     Answer: 7
#
#   Question: What is the Exit Month?
#     Answer: 7
#
#   Question: What is the Outcome Year?
#     Answer: 2014
#
#   Question: What is the Outcome Weekday?
#     Answer: Tuesday
#
#   Question: What is the Outcome Hour?
#     Answer: 16
#
#   Question: What is the Coat Pattern?
#     Answer: orange
#
#   Question: What is the Coat?
#     Answer: orange

# %% [markdown]
# ### Identify outliers and bad data (Data Wrangling with Python pg. 169 – 174)

# %% [markdown]
#  ##### Find Missing Values - Missingness

# %%
# I chose to create a dictionary totalling the columns with missing values and counting them
index = 0
mcount = 0
misscol = {}
while index < len(new_list):
    for dictkey, dictval in new_list[index].items():
        if not dictval:
            mcount += 1
            # Using get() 
            # Increment value in dictionary 
            misscol[dictkey] = misscol.get(dictkey, 0) + 1
            # DEBUG print("Missing value for {} {}:".format(dictkey,dictval))
    index += 1
print("\nColumns with missing values showing totals:\n")
pprint.pprint(misscol)
print("\nTotal missing values: {}".format(mcount))
# Out:
# Columns with missing values showing totals:
#
# {'Color': 3626,
#  'Name': 12774,
#  'Outcome Subtype': 10780,
#  'Outcome Type': 3,
#  'Secondary Breed ': 29369,
#  'Secondary Color': 19067}
#
# Total missing values: 75619

# %% [markdown]
#  ##### Find Missing Values - NA, na ...

# %%
# I chose to create a dictionary totalling the columns with NA values and counting them
# Similar to code above - none were found in this data set.

nalist = ["NA", "Na", "na"]
nindex = 0
ncount = 0
nacol = {}
while nindex < len(new_list):
    # print(nindex)
    for dictkey, dictval in new_list[nindex].items():
         # print(dictval)
        if dictval in nalist:
            ncount += 1
            # Using get() 
            # Increment value in dictionary 
            nacol[dictkey] = nacol.get(dictkey, 0) + 1
    nindex += 1
print("\nColumns with NA values showing totals:\n")
pprint.pprint(nacol)
print("\nTotal NA values: {}".format(ncount))
# Out:
# Columns with NA values showing totals:
#
# {}
#
# Total NA values: 0

# %% [markdown]
# #### Evaluate data types of each column

# %%
# Initialize values
datatypes = {} 

start_dict = {'digit': 0, 'boolean': 0,
              'empty': 0, 'time_related': 0,
              'text': 0, 'alphanumeric': 0, 'unknown': 0
              } 
xindex = 0
xcount = 0
xcol = {}

# Loop through total count of list
while xindex < len(new_list):
    # print(nindex)
    # loop through every dictionary element in list of dictionaries
    for dictkey,dictval in new_list[xindex].items():
        # print(dictval)
        question = dictkey
        answer = dictval
        key = 'unknown' 
        # Is it a digit?
        if answer.isdigit(): 
            key = 'digit'
        # Is it a boolean?
        elif answer in ['Yes', 'No', 'True', 'False']: 
            key = 'boolean'
        #  Empty?
        elif answer.isspace(): 
            key = 'empty'
        # Does it indicate date type?
        elif answer.find('/') > 0 or answer.find(':') > 0: 
            key = 'time_related'
        # Is it text?
        elif answer.isalpha(): 
            key = 'text'
        # Is it alphanumeric?
        elif answer.isalnum(): 
            key = 'alphanumeric'
        # Can't classify.
        if question not in datatypes.keys(): 
            datatypes[question] = start_dict.copy() 
        datatypes[question][key] += 1 
    xindex += 1
print("\nDictionary of dictionaries containing columns and analysis of data type with totals:\n")
pprint.pprint(datatypes)
# Out:
# Dictionary of dictionaries containing columns and analysis of data type with totals:
#
# {'Age Group': {'alphanumeric': 0,
#                'boolean': 0,
#                'digit': 0,
#                'empty': 0,
#                'text': 0,
#                'time_related': 0,
#                'unknown': 29421},
#  'Animal ID': {'alphanumeric': 29421,
#                'boolean': 0,
#                'digit': 0,
#                'empty': 0,
#                'text': 0,
#                'time_related': 0,
#                'unknown': 0},
#  'Animal Type': {'alphanumeric': 0,
#                  'boolean': 0,
#                  'digit': 0,
#                  'empty': 0,
#                  'text': 29421,
#                  'time_related': 0,
#                  'unknown': 0},
#  'Breed': {'alphanumeric': 0,
#            'boolean': 0,
#            'digit': 0,
#            'empty': 0,
#            'text': 1459,
#            'time_related': 52,
#            'unknown': 27910},
#  'CFA Breed': {'alphanumeric': 0,
#                'boolean': 29421,
#                'digit': 0,
#                'empty': 0,
#                'text': 0,
#                'time_related': 0,
#                'unknown': 0},
#  'Coat': {'alphanumeric': 0,
#           'boolean': 0,
#           'digit': 0,
#           'empty': 0,
#           'text': 24696,
#           'time_related': 0,
#           'unknown': 4725},
#  'Coat Pattern': {'alphanumeric': 0,
#                   'boolean': 0,
#                   'digit': 0,
#                   'empty': 0,
#                   'text': 24696,
#                   'time_related': 0,
#                   'unknown': 4725},
#  'Color': {'alphanumeric': 0,
#            'boolean': 0,
#            'digit': 0,
#            'empty': 0,
#            'text': 15341,
#            'time_related': 9967,
#            'unknown': 4113},
#  'Count': {'alphanumeric': 0,
#            'boolean': 0,
#            'digit': 29421,
#            'empty': 0,
#            'text': 0,
#            'time_related': 0,
#            'unknown': 0},
#  'DOB Month': {'alphanumeric': 0,
#                'boolean': 0,
#                'digit': 29421,
#                'empty': 0,
#                'text': 0,
#                'time_related': 0,
#                'unknown': 0},
#  'DOB Month-Year': {'alphanumeric': 0,
#                     'boolean': 0,
#                     'digit': 0,
#                     'empty': 0,
#                     'text': 0,
#                     'time_related': 0,
#                     'unknown': 29421},
#  'DOB Year': {'alphanumeric': 0,
#               'boolean': 0,
#               'digit': 29421,
#               'empty': 0,
#               'text': 0,
#               'time_related': 0,
#               'unknown': 0},
#  'Date Of Birth': {'alphanumeric': 0,
#                    'boolean': 0,
#                    'digit': 0,
#                    'empty': 0,
#                    'text': 0,
#                    'time_related': 29421,
#                    'unknown': 0},
#  'Domestic Breed': {'alphanumeric': 0,
#                     'boolean': 29421,
#                     'digit': 0,
#                     'empty': 0,
#                     'text': 0,
#                     'time_related': 0,
#                     'unknown': 0},
#  'Exit Month': {'alphanumeric': 0,
#                 'boolean': 0,
#                 'digit': 29421,
#                 'empty': 0,
#                 'text': 0,
#                 'time_related': 0,
#                 'unknown': 0},
#  'Name': {'alphanumeric': 0,
#           'boolean': 0,
#           'digit': 0,
#           'empty': 0,
#           'text': 7099,
#           'time_related': 2,
#           'unknown': 22320},
#  'Outcome Age': {'alphanumeric': 0,
#                  'boolean': 0,
#                  'digit': 0,
#                  'empty': 0,
#                  'text': 0,
#                  'time_related': 0,
#                  'unknown': 29421},
#  'Outcome Age Timestamp': {'alphanumeric': 0,
#                            'boolean': 0,
#                            'digit': 0,
#                            'empty': 0,
#                            'text': 0,
#                            'time_related': 29421,
#                            'unknown': 0},
#  'Outcome Age in Days': {'alphanumeric': 0,
#                          'boolean': 0,
#                          'digit': 29421,
#                          'empty': 0,
#                          'text': 0,
#                          'time_related': 0,
#                          'unknown': 0},
#  'Outcome Age in Years': {'alphanumeric': 0,
#                           'boolean': 0,
#                           'digit': 0,
#                           'empty': 0,
#                           'text': 0,
#                           'time_related': 0,
#                           'unknown': 29421},
#  'Outcome Cat-Kitten': {'alphanumeric': 0,
#                         'boolean': 0,
#                         'digit': 0,
#                         'empty': 0,
#                         'text': 29421,
#                         'time_related': 0,
#                         'unknown': 0},
#  'Outcome Hour': {'alphanumeric': 0,
#                   'boolean': 0,
#                   'digit': 29421,
#                   'empty': 0,
#                   'text': 0,
#                   'time_related': 0,
#                   'unknown': 0},
#  'Outcome Month-Year': {'alphanumeric': 0,
#                         'boolean': 0,
#                         'digit': 0,
#                         'empty': 0,
#                         'text': 0,
#                         'time_related': 29421,
#                         'unknown': 0},
#  'Outcome Sex': {'alphanumeric': 0,
#                  'boolean': 0,
#                  'digit': 0,
#                  'empty': 0,
#                  'text': 29421,
#                  'time_related': 0,
#                  'unknown': 0},
#  'Outcome Sex Age': {'alphanumeric': 0,
#                      'boolean': 0,
#                      'digit': 0,
#                      'empty': 0,
#                      'text': 0,
#                      'time_related': 0,
#                      'unknown': 29421},
#  'Outcome Subtype': {'alphanumeric': 0,
#                      'boolean': 0,
#                      'digit': 0,
#                      'empty': 0,
#                      'text': 18170,
#                      'time_related': 0,
#                      'unknown': 11251},
#  'Outcome Type': {'alphanumeric': 0,
#                   'boolean': 0,
#                   'digit': 0,
#                   'empty': 0,
#                   'text': 27954,
#                   'time_related': 0,
#                   'unknown': 1467},
#  'Outcome Weekday': {'alphanumeric': 0,
#                      'boolean': 0,
#                      'digit': 0,
#                      'empty': 0,
#                      'text': 29421,
#                      'time_related': 0,
#                      'unknown': 0},
#  'Outcome Year': {'alphanumeric': 0,
#                   'boolean': 0,
#                   'digit': 29421,
#                   'empty': 0,
#                   'text': 0,
#                   'time_related': 0,
#                   'unknown': 0},
#  'Period Range': {'alphanumeric': 0,
#                   'boolean': 0,
#                   'digit': 29421,
#                   'empty': 0,
#                   'text': 0,
#                   'time_related': 0,
#                   'unknown': 0},
#  'Periods': {'alphanumeric': 0,
#              'boolean': 0,
#              'digit': 29421,
#              'empty': 0,
#              'text': 0,
#              'time_related': 0,
#              'unknown': 0},
#  'Primary Breed': {'alphanumeric': 0,
#                    'boolean': 0,
#                    'digit': 0,
#                    'empty': 0,
#                    'text': 1489,
#                    'time_related': 0,
#                    'unknown': 27932},
#  'Primary Color': {'alphanumeric': 0,
#                    'boolean': 0,
#                    'digit': 0,
#                    'empty': 0,
#                    'text': 20638,
#                    'time_related': 0,
#                    'unknown': 8783},
#  'Secondary Breed ': {'alphanumeric': 0,
#                       'boolean': 0,
#                       'digit': 0,
#                       'empty': 0,
#                       'text': 19,
#                       'time_related': 0,
#                       'unknown': 29402},
#  'Secondary Color': {'alphanumeric': 0,
#                      'boolean': 0,
#                      'digit': 0,
#                      'empty': 0,
#                      'text': 10333,
#                      'time_related': 0,
#                      'unknown': 19088},
#  'Sex': {'alphanumeric': 0,
#          'boolean': 0,
#          'digit': 0,
#          'empty': 0,
#          'text': 29421,
#          'time_related': 0,
#          'unknown': 0},
#  'Spay-Neuter': {'alphanumeric': 0,
#                  'boolean': 29421,
#                  'digit': 0,
#                  'empty': 0,
#                  'text': 0,
#                  'time_related': 0,
#                  'unknown': 0}}

# %% [markdown]
# ### Find Duplicates
#
# ##### First discover what makes the data unique

# %%
# Variable initialization
dictlist = []
pairlist = []
colorlist = []
dindex = 0
# dcount = 0
# dupcol = {}

# The code exmaple from the text would allow me to do this with shorter code, but given 
# that I was testing two different possible unique values at inception, this method allowed me to 
# run through the data once addressing both possibilities.  
while dindex < len(new_list):
    for dictkey, dictval in new_list[dindex].items():
        if dictkey == "Animal ID":
            # Just looking at atnimal id
            dictlist.append(dictval)
            # Storing for later pairing with outcome date
            animal = dictval
            # Create pair for further analysis
        if dictkey == "Outcome Age Timestamp":
            # DEBUG print(dictval)
            outcomedt = datetime.datetime.strptime(dictval, '%Y-%m-%d %H:%M:%S')
            # print(outcomedt)
            # Strip out spaces, dashes and colons and build my own key
            pairlist.append(animal + "-" + outcomedt.strftime("%Y-%m-%d %H:%M:%S"))
    dindex += 1

# %% [markdown]
# ##### Animal ID alone is not enough to express uniqueness as this proves.

# %%
# Is animal id unique - NO
unq, count = np.unique(dictlist, return_counts=True)    

print("\nSummary of duplicates only looking at animal id:\n")
print(unq[count>1])

# cout each non unique value
dcount = len(unq[count>1])

print("\nTotal animal id values with duplicates: {}".format(dcount))
# Out:
# Summary of duplicates only looking at animal id:
#
# ['A282897' 'A304036' 'A318574' ... 'A764345' 'A764565' 'A765350']
#
# Total animal id values with duplicates: 1107

# %% [markdown]
# ##### A new key is required.  I selected animal id and outcome date.

# %%
# Is animal id plus outcome date unique - YES, but legitimate duplicates remain and need to be dealt with. 
unq, count = np.unique(pairlist, return_counts=True) 

# cout each non unique value
dcount = len(unq[count>1])

print("\nSummary of duplicates looking at the combination of animal id and outcome date after removing special characters:\n")
duplist = unq[count>1].tolist()
pprint.pprint(duplist)


print("\nTotal animal id plus outcome date values (using new key) with duplicates: {}".format(dcount))
# Out:
# Summary of duplicates looking at the combination of animal id and outcome date after removing special characters:
#
# ['A660948-2013-11-03 18:16:00',
#  'A682781-2014-07-03 09:00:00',
#  'A683782-2014-07-16 09:00:00',
#  'A686827-2014-08-28 09:00:00',
#  'A695798-2015-01-23 12:34:00',
#  'A696688-2015-03-26 19:05:00',
#  'A748204-2017-05-04 18:04:00']
#
# Total animal id plus outcome date values (using new key) with duplicates: 7

# %% [markdown]
# ##### Validate remaining duplicates are actually duplicates.

# %%
# Run through data again showing duplicate entries.
# Since there were only 7 rows duplicated a visual verification should suffice.

dictlist = []
pairlist = []
colorlist = []
dindex = 0

while dindex < len(new_list):
    for dictkey, dictval in new_list[dindex].items():
        if dictkey == "Animal ID":
            # Just looking at atnimal id
            dictlist.append(dictval)
            # Storing for later pairing with outcome date
            animal = dictval
            # Create pair for further analysis
        if dictkey == "Outcome Age Timestamp":
            # DEBUG print(dictval)
            outcomedt = datetime.datetime.strptime(dictval, '%Y-%m-%d %H:%M:%S')
            # print(outcomedt)
            # Strip out spaces, dashes and colons and build my own key
            if (animal + "-" + outcomedt.strftime("%Y-%m-%d %H:%M:%S")) in duplist:
                print(new_list[dindex])
    dindex += 1
# Out:
# {'Outcome Age': '2 years', 'Animal ID': 'A686827', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': '', 'Primary Color': 'Breed Specific', 'Secondary Color': '', 'Date Of Birth': '2012-02-27 00:00:00', 'Outcome Age Timestamp': '2014-08-28 09:00:00', 'Outcome Month-Year': '2014-08-28T09:00:00', 'DOB Month-Year': '2014-08', 'Name': '', 'Outcome Subtype': 'SCRP', 'Outcome Type': 'Transfer', 'Outcome Sex': 'Female', 'Count': '1', 'Sex': 'Female', 'Outcome Sex Age': 'Spayed Female Cat', 'Spay-Neuter': 'Yes', 'Periods': '2', 'Period Range': '365', 'Outcome Age in Days': '730', 'Outcome Age in Years': '2.0', 'Outcome Cat-Kitten': 'Cat', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2012', 'DOB Month': '2', 'Exit Month': '8', 'Outcome Year': '2014', 'Outcome Weekday': 'Thursday', 'Outcome Hour': '9', 'Coat Pattern': 'calico', 'Coat': 'calico'}
# {'Outcome Age': '2 years', 'Animal ID': 'A686827', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': '', 'Primary Color': 'Breed Specific', 'Secondary Color': '', 'Date Of Birth': '2012-02-27 00:00:00', 'Outcome Age Timestamp': '2014-08-28 09:00:00', 'Outcome Month-Year': '2014-08-28T09:00:00', 'DOB Month-Year': '2014-08', 'Name': '', 'Outcome Subtype': 'SCRP', 'Outcome Type': 'Transfer', 'Outcome Sex': 'Female', 'Count': '1', 'Sex': 'Female', 'Outcome Sex Age': 'Spayed Female Cat', 'Spay-Neuter': 'Yes', 'Periods': '2', 'Period Range': '365', 'Outcome Age in Days': '730', 'Outcome Age in Years': '2.0', 'Outcome Cat-Kitten': 'Cat', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2012', 'DOB Month': '2', 'Exit Month': '8', 'Outcome Year': '2014', 'Outcome Weekday': 'Thursday', 'Outcome Hour': '9', 'Coat Pattern': 'calico', 'Coat': 'calico'}
# {'Outcome Age': '4 months', 'Animal ID': 'A683782', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'brown', 'Primary Color': 'brown', 'Secondary Color': '', 'Date Of Birth': '2014-02-15 00:00:00', 'Outcome Age Timestamp': '2014-07-16 09:00:00', 'Outcome Month-Year': '2014-07-16T09:00:00', 'DOB Month-Year': '2014-07', 'Name': '', 'Outcome Subtype': 'SCRP', 'Outcome Type': 'Transfer', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Kitten', 'Spay-Neuter': 'Yes', 'Periods': '4', 'Period Range': '30', 'Outcome Age in Days': '120', 'Outcome Age in Years': '0.3287671232876712', 'Outcome Cat-Kitten': 'Kitten', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2014', 'DOB Month': '2', 'Exit Month': '7', 'Outcome Year': '2014', 'Outcome Weekday': 'Wednesday', 'Outcome Hour': '9', 'Coat Pattern': 'brown', 'Coat': 'brown'}
# {'Outcome Age': '4 months', 'Animal ID': 'A683782', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'brown', 'Primary Color': 'brown', 'Secondary Color': '', 'Date Of Birth': '2014-02-15 00:00:00', 'Outcome Age Timestamp': '2014-07-16 09:00:00', 'Outcome Month-Year': '2014-07-16T09:00:00', 'DOB Month-Year': '2014-07', 'Name': '', 'Outcome Subtype': 'SCRP', 'Outcome Type': 'Transfer', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Kitten', 'Spay-Neuter': 'Yes', 'Periods': '4', 'Period Range': '30', 'Outcome Age in Days': '120', 'Outcome Age in Years': '0.3287671232876712', 'Outcome Cat-Kitten': 'Kitten', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2014', 'DOB Month': '2', 'Exit Month': '7', 'Outcome Year': '2014', 'Outcome Weekday': 'Wednesday', 'Outcome Hour': '9', 'Coat Pattern': 'brown', 'Coat': 'brown'}
# {'Outcome Age': '1 year', 'Animal ID': 'A682781', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'white/black', 'Primary Color': 'white', 'Secondary Color': 'black', 'Date Of Birth': '2013-01-02 00:00:00', 'Outcome Age Timestamp': '2014-07-03 09:00:00', 'Outcome Month-Year': '2014-07-03T09:00:00', 'DOB Month-Year': '2014-07', 'Name': '', 'Outcome Subtype': 'SCRP', 'Outcome Type': 'Transfer', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Cat', 'Spay-Neuter': 'Yes', 'Periods': '1', 'Period Range': '365', 'Outcome Age in Days': '365', 'Outcome Age in Years': '1.0', 'Outcome Cat-Kitten': 'Cat', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2013', 'DOB Month': '1', 'Exit Month': '7', 'Outcome Year': '2014', 'Outcome Weekday': 'Thursday', 'Outcome Hour': '9', 'Coat Pattern': 'white', 'Coat': 'white'}
# {'Outcome Age': '1 year', 'Animal ID': 'A682781', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'white/black', 'Primary Color': 'white', 'Secondary Color': 'black', 'Date Of Birth': '2013-01-02 00:00:00', 'Outcome Age Timestamp': '2014-07-03 09:00:00', 'Outcome Month-Year': '2014-07-03T09:00:00', 'DOB Month-Year': '2014-07', 'Name': '', 'Outcome Subtype': 'SCRP', 'Outcome Type': 'Transfer', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Cat', 'Spay-Neuter': 'Yes', 'Periods': '1', 'Period Range': '365', 'Outcome Age in Days': '365', 'Outcome Age in Years': '1.0', 'Outcome Cat-Kitten': 'Cat', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2013', 'DOB Month': '1', 'Exit Month': '7', 'Outcome Year': '2014', 'Outcome Weekday': 'Thursday', 'Outcome Hour': '9', 'Coat Pattern': 'white', 'Coat': 'white'}
# {'Outcome Age': '3 months', 'Animal ID': 'A660948', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'brown /white', 'Primary Color': 'brown ', 'Secondary Color': 'white', 'Date Of Birth': '2013-07-08 00:00:00', 'Outcome Age Timestamp': '2013-11-03 18:16:00', 'Outcome Month-Year': '2013-11-03T18:16:00', 'DOB Month-Year': '2013-11', 'Name': '*Roy', 'Outcome Subtype': '', 'Outcome Type': 'Adoption', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Kitten', 'Spay-Neuter': 'Yes', 'Periods': '3', 'Period Range': '30', 'Outcome Age in Days': '90', 'Outcome Age in Years': '0.2465753424657534', 'Outcome Cat-Kitten': 'Kitten', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2013', 'DOB Month': '7', 'Exit Month': '11', 'Outcome Year': '2013', 'Outcome Weekday': 'Sunday', 'Outcome Hour': '18', 'Coat Pattern': 'brown ', 'Coat': 'brown '}
# {'Outcome Age': '3 months', 'Animal ID': 'A660948', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'brown /white', 'Primary Color': 'brown ', 'Secondary Color': 'white', 'Date Of Birth': '2013-07-08 00:00:00', 'Outcome Age Timestamp': '2013-11-03 18:16:00', 'Outcome Month-Year': '2013-11-03T18:16:00', 'DOB Month-Year': '2013-11', 'Name': '*Roy', 'Outcome Subtype': '', 'Outcome Type': 'Adoption', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Kitten', 'Spay-Neuter': 'Yes', 'Periods': '3', 'Period Range': '30', 'Outcome Age in Days': '90', 'Outcome Age in Years': '0.2465753424657534', 'Outcome Cat-Kitten': 'Kitten', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2013', 'DOB Month': '7', 'Exit Month': '11', 'Outcome Year': '2013', 'Outcome Weekday': 'Sunday', 'Outcome Hour': '18', 'Coat Pattern': 'brown ', 'Coat': 'brown '}
# {'Outcome Age': '10 months', 'Animal ID': 'A695798', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'orange', 'Primary Color': 'orange', 'Secondary Color': '', 'Date Of Birth': '2014-02-23 00:00:00', 'Outcome Age Timestamp': '2015-01-23 12:34:00', 'Outcome Month-Year': '2015-01-23T12:34:00', 'DOB Month-Year': '2015-01', 'Name': 'Jim', 'Outcome Subtype': 'Suffering', 'Outcome Type': 'Euthanasia', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Cat', 'Spay-Neuter': 'Yes', 'Periods': '10', 'Period Range': '30', 'Outcome Age in Days': '300', 'Outcome Age in Years': '0.821917808219178', 'Outcome Cat-Kitten': 'Cat', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2014', 'DOB Month': '2', 'Exit Month': '1', 'Outcome Year': '2015', 'Outcome Weekday': 'Friday', 'Outcome Hour': '12', 'Coat Pattern': 'orange', 'Coat': 'orange'}
# {'Outcome Age': '10 months', 'Animal ID': 'A695798', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'orange', 'Primary Color': 'orange', 'Secondary Color': '', 'Date Of Birth': '2014-02-23 00:00:00', 'Outcome Age Timestamp': '2015-01-23 12:34:00', 'Outcome Month-Year': '2015-01-23T12:34:00', 'DOB Month-Year': '2015-01', 'Name': 'Jim', 'Outcome Subtype': 'Suffering', 'Outcome Type': 'Euthanasia', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Cat', 'Spay-Neuter': 'Yes', 'Periods': '10', 'Period Range': '30', 'Outcome Age in Days': '300', 'Outcome Age in Years': '0.821917808219178', 'Outcome Cat-Kitten': 'Cat', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2014', 'DOB Month': '2', 'Exit Month': '1', 'Outcome Year': '2015', 'Outcome Weekday': 'Friday', 'Outcome Hour': '12', 'Coat Pattern': 'orange', 'Coat': 'orange'}
# {'Outcome Age': '3 years', 'Animal ID': 'A696688', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': '/white', 'Primary Color': 'Breed Specific', 'Secondary Color': 'white', 'Date Of Birth': '2012-02-10 00:00:00', 'Outcome Age Timestamp': '2015-03-26 19:05:00', 'Outcome Month-Year': '2015-03-26T19:05:00', 'DOB Month-Year': '2015-03', 'Name': 'Mari', 'Outcome Subtype': '', 'Outcome Type': 'Adoption', 'Outcome Sex': 'Female', 'Count': '1', 'Sex': 'Female', 'Outcome Sex Age': 'Spayed Female Cat', 'Spay-Neuter': 'Yes', 'Periods': '3', 'Period Range': '365', 'Outcome Age in Days': '1095', 'Outcome Age in Years': '3.0', 'Outcome Cat-Kitten': 'Cat', 'Age Group': '(2.2, 4.4]', 'DOB Year': '2012', 'DOB Month': '2', 'Exit Month': '3', 'Outcome Year': '2015', 'Outcome Weekday': 'Thursday', 'Outcome Hour': '19', 'Coat Pattern': 'calico', 'Coat': 'calico'}
# {'Outcome Age': '3 years', 'Animal ID': 'A696688', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': '/white', 'Primary Color': 'Breed Specific', 'Secondary Color': 'white', 'Date Of Birth': '2012-02-10 00:00:00', 'Outcome Age Timestamp': '2015-03-26 19:05:00', 'Outcome Month-Year': '2015-03-26T19:05:00', 'DOB Month-Year': '2015-03', 'Name': 'Mari', 'Outcome Subtype': '', 'Outcome Type': 'Adoption', 'Outcome Sex': 'Female', 'Count': '1', 'Sex': 'Female', 'Outcome Sex Age': 'Spayed Female Cat', 'Spay-Neuter': 'Yes', 'Periods': '3', 'Period Range': '365', 'Outcome Age in Days': '1095', 'Outcome Age in Years': '3.0', 'Outcome Cat-Kitten': 'Cat', 'Age Group': '(2.2, 4.4]', 'DOB Year': '2012', 'DOB Month': '2', 'Exit Month': '3', 'Outcome Year': '2015', 'Outcome Weekday': 'Thursday', 'Outcome Hour': '19', 'Coat Pattern': 'calico', 'Coat': 'calico'}
# {'Outcome Age': '2 months', 'Animal ID': 'A748204', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'white/blue', 'Primary Color': 'white', 'Secondary Color': 'blue', 'Date Of Birth': '2017-02-04 00:00:00', 'Outcome Age Timestamp': '2017-05-04 18:04:00', 'Outcome Month-Year': '2017-05-04T18:04:00', 'DOB Month-Year': '2017-05', 'Name': 'Bob', 'Outcome Subtype': '', 'Outcome Type': 'Adoption', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Kitten', 'Spay-Neuter': 'Yes', 'Periods': '2', 'Period Range': '30', 'Outcome Age in Days': '60', 'Outcome Age in Years': '0.1643835616438356', 'Outcome Cat-Kitten': 'Kitten', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2017', 'DOB Month': '2', 'Exit Month': '5', 'Outcome Year': '2017', 'Outcome Weekday': 'Thursday', 'Outcome Hour': '18', 'Coat Pattern': 'white', 'Coat': 'white'}
# {'Outcome Age': '2 months', 'Animal ID': 'A748204', 'Animal Type': 'Cat', 'Breed': 'domestic shorthair', 'Primary Breed': 'domestic shorthair', 'Secondary Breed ': '', 'CFA Breed': 'False', 'Domestic Breed': 'True', 'Color': 'white/blue', 'Primary Color': 'white', 'Secondary Color': 'blue', 'Date Of Birth': '2017-02-04 00:00:00', 'Outcome Age Timestamp': '2017-05-04 18:04:00', 'Outcome Month-Year': '2017-05-04T18:04:00', 'DOB Month-Year': '2017-05', 'Name': 'Bob', 'Outcome Subtype': '', 'Outcome Type': 'Adoption', 'Outcome Sex': 'Male', 'Count': '1', 'Sex': 'Male', 'Outcome Sex Age': 'Neutered Male Kitten', 'Spay-Neuter': 'Yes', 'Periods': '2', 'Period Range': '30', 'Outcome Age in Days': '60', 'Outcome Age in Years': '0.1643835616438356', 'Outcome Cat-Kitten': 'Kitten', 'Age Group': '(-0.022, 2.2]', 'DOB Year': '2017', 'DOB Month': '2', 'Exit Month': '5', 'Outcome Year': '2017', 'Outcome Weekday': 'Thursday', 'Outcome Hour': '18', 'Coat Pattern': 'white', 'Coat': 'white'}

# %%
# New key that can be used after duplicates are handled

print("\nNew unique key that can be used after duplicates are removed from data set with")

# set() method is used to convert any of the iterable to the distinct element and sorted sequence of iterable elements
# taken from https://www.geeksforgeeks.org/python-set-method/

keylist = set(unq)
lenlist = len(keylist)
print("  a total unique entry count of: {}\n".format(lenlist))
# Out:
# New unique key that can be used after duplicates are removed from data set with
#   a total unique entry count of: 29414

# %%
# Display new valid unique key
pprint.pprint(keylist)
# Out:
# {'A191351-2015-11-17 13:29:00',
#  'A197810-2014-12-22 15:23:00',
#  'A214991-2013-12-14 13:28:00',
#  'A234161-2013-12-27 17:02:00',
#  'A243903-2014-01-05 11:45:00',
#  'A251268-2018-01-29 16:07:00',
#  'A258441-2014-11-28 14:27:00',
#  'A260631-2014-10-20 13:50:00',
#  'A261770-2014-11-07 15:51:00',
#  'A275975-2013-10-12 11:27:00',
#  'A276644-2017-01-02 11:03:00',
#  'A279045-2015-02-13 11:15:00',
#  'A282897-2013-12-28 17:05:00',
#  'A282897-2015-07-11 16:49:00',
#  'A287217-2014-10-31 13:06:00',
#  'A290917-2014-07-08 14:46:00',
#  'A292482-2014-07-07 11:06:00',
#  'A293138-2017-04-26 12:54:00',
#  'A295822-2015-05-09 18:47:00',
#  'A301824-2016-10-10 19:09:00',
#  'A664972-2013-11-22 15:48:00',
#  'A664973-2013-11-17 12:59:00',
#  'A664974-2013-11-17 12:10:00',
#  'A664975-2013-11-17 12:10:00',
#  'A664986-2013-10-13 15:24:00',
#  'A664994-2013-12-01 18:05:00',
#  'A665005-2013-10-15 13:09:00',
#  'A665015-2013-10-26 11:22:00',
#  'A665019-2013-12-05 15:30:00',
#  'A665020-2013-10-13 15:24:00',
#  'A665021-2013-10-12 15:22:00',
#  'A665022-2013-10-16 18:29:00',
#  'A665023-2013-10-22 14:41:00',
#  'A665024-2013-10-21 12:18:00',
#  'A665025-2013-10-27 17:42:00',
#  'A665030-2013-10-27 14:45:00',
#  'A665034-2013-10-24 15:24:00',
#  'A665042-2013-10-12 19:24:00',
#  'A665043-2013-10-12 19:24:00',
#  'A665063-2013-10-13 15:13:00',
#  'A665064-2013-10-13 15:14:00',
#  'A665065-2013-10-13 15:14:00',
#  'A665069-2013-12-07 16:46:00',
#  'A665070-2013-12-07 16:45:00',
#  'A665071-2013-12-07 14:57:00',
#  'A665072-2013-12-07 14:57:00',
#  'A665075-2013-10-18 13:15:00',
#  'A665078-2013-10-14 15:50:00',
#  'A665081-2013-11-12 16:41:00',
#  'A665084-2013-10-14 16:05:00',
#  'A665086-2013-11-09 00:07:00',
#  'A665087-2013-11-09 00:09:00',
#  'A665088-2013-12-24 12:48:00',
#  'A665093-2013-10-18 13:05:00',
#  'A665098-2013-10-14 16:05:00',
#  'A665099-2013-10-14 16:05:00',
#  'A665101-2014-04-19 10:42:00',
#  'A665122-2013-10-14 11:54:00',
#  'A665124-2013-10-14 12:16:00',
#  'A665125-2013-10-14 12:16:00',
#  'A665126-2013-10-14 12:16:00',
#  'A665127-2013-10-14 12:17:00',
#  'A665128-2013-10-14 12:17:00',
#  'A665129-2013-10-14 12:17:00',
#  'A665136-2013-10-14 11:14:00',
#  'A665139-2013-10-14 12:15:00',
#  'A665140-2013-10-14 12:16:00',
#  'A665143-2013-11-24 17:52:00',
#  'A665145-2013-12-16 17:32:00',
#  'A665153-2013-10-18 17:28:00',
#  'A665157-2013-10-14 14:07:00',
#  'A665181-2013-10-27 14:43:00',
#  'A665182-2013-10-27 14:42:00',
#  'A665185-2013-12-03 15:35:00',
#  'A665189-2013-10-15 09:52:00',
#  'A665190-2013-10-15 10:30:00',
#  'A665199-2013-10-16 16:51:00',
#  'A665200-2013-10-16 16:51:00',
#  'A665201-2013-10-16 16:52:00',
#  'A665205-2013-10-15 13:10:00',
#  'A665207-2013-10-15 13:10:00',
#  'A665208-2013-10-15 13:10:00',
#  'A665209-2013-10-20 14:47:00',
#  'A665229-2013-10-18 18:55:00',
#  'A665246-2013-10-18 12:31:00',
#  'A665252-2013-10-15 18:44:00',
#  'A665256-2013-10-15 19:02:00',
#  'A665257-2013-10-20 08:25:00',
#  'A665258-2013-12-04 12:44:00',
#  'A665259-2013-12-07 16:01:00',
#  'A665260-2013-12-06 09:27:00',
#  'A665261-2013-12-13 11:51:00',
#  'A665262-2013-12-09 18:43:00',
#  'A665268-2013-10-17 17:59:00',
#  'A665278-2013-10-17 17:59:00',
#  'A665280-2013-10-17 17:59:00',
#  'A665283-2013-10-26 14:19:00',
#  'A665284-2013-10-19 18:22:00',
#  'A665285-2013-10-19 17:16:00',
#  'A665291-2013-10-16 11:51:00',
#  'A665292-2013-10-16 11:52:00',
#  'A665297-2013-10-16 11:50:00',
#  'A665298-2013-10-16 11:50:00',
#  'A665299-2013-10-16 11:50:00',
#  'A665300-2013-10-16 11:50:00',
#  'A665303-2013-10-17 17:58:00',
#  'A665305-2013-10-22 13:36:00',
#  'A665306-2013-11-13 17:59:00',
#  'A665307-2013-10-27 14:45:00',
#  'A665310-2013-12-01 15:27:00',
#  'A665311-2013-11-18 14:22:00',
#  'A665312-2013-11-25 17:42:00',
#  'A665314-2013-12-22 23:37:00',
#  'A665318-2013-12-24 12:49:00',
#  'A665348-2013-10-20 11:47:00',
#  'A665354-2013-10-18 12:31:00',
#  'A665361-2013-10-25 11:17:00',
#  'A665362-2013-10-25 11:17:00',
#  'A665387-2013-10-17 13:32:00',
#  'A665388-2013-10-17 13:32:00',
#  'A665391-2013-12-05 15:39:00',
#  'A665392-2013-10-19 15:48:00',
#  'A665393-2013-11-01 14:21:00',
#  'A665394-2013-10-25 18:31:00',
#  'A665395-2013-10-29 12:15:00',
#  'A665396-2013-10-29 12:16:00',
#  'A665397-2013-11-11 17:06:00',
#  'A665398-2013-11-10 16:45:00',
#  'A665399-2013-11-09 11:29:00',
#  'A665400-2013-11-10 16:10:00',
#  'A665401-2013-11-09 18:50:00',
#  'A665406-2013-10-19 15:32:00',
#  'A665407-2013-10-19 15:32:00',
#  'A665408-2013-10-19 15:33:00',
#  'A665409-2013-10-19 15:33:00',
#  'A665424-2013-11-03 11:56:00',
#  'A665425-2013-11-30 12:54:00',
#  'A665426-2013-11-16 17:09:00',
#  'A665427-2013-10-20 13:37:00',
#  'A665428-2013-10-20 13:37:00',
#  'A665429-2013-11-03 23:52:00',
#  'A665444-2013-10-25 12:08:00',
#  'A665446-2013-10-25 15:13:00',
#  'A665447-2013-11-09 00:09:00',
#  'A665458-2013-10-22 17:49:00',
#  'A665467-2013-10-21 15:37:00',
#  'A665468-2013-12-13 17:11:00',
#  'A665469-2013-12-13 17:10:00',
#  'A665470-2013-12-13 17:47:00',
#  'A665471-2013-12-14 08:27:00',
#  'A665472-2013-10-22 18:11:00',
#  'A665473-2013-10-24 15:54:00',
#  'A665474-2013-12-26 17:56:00',
#  'A665484-2013-10-18 14:53:00',
#  'A665496-2013-10-22 17:54:00',
#  'A665546-2013-10-21 16:03:00',
#  'A665549-2013-11-02 12:47:00',
#  'A665549-2016-04-02 15:19:00',
#  'A665549-2016-06-29 13:18:00',
#  'A665550-2013-10-23 16:53:00',
#  'A665551-2013-12-12 13:11:00',
#  'A665552-2013-10-19 15:30:00',
#  'A665553-2013-10-22 17:52:00',
#  'A665571-2013-10-19 16:23:00',
#  'A665578-2013-11-04 15:08:00',
#  'A665579-2013-11-04 15:09:00',
#  'A665580-2013-10-27 16:02:00',
#  'A665583-2013-10-20 13:37:00',
#  'A665584-2013-10-24 15:43:00',
#  'A665585-2013-10-25 15:08:00',
#  'A665586-2013-10-25 15:08:00',
#  'A665587-2013-11-27 14:36:00',
#  'A665590-2013-11-12 17:20:00',
#  'A665590-2015-09-10 17:24:00',
#  'A665593-2013-12-07 17:33:00',
#  'A665603-2013-11-05 16:18:00',
#  'A665608-2013-10-20 14:59:00',
#  'A665609-2013-10-20 15:00:00',
#  'A665610-2013-10-20 15:00:00',
#  'A665611-2013-10-20 15:00:00',
#  'A665614-2013-10-20 13:01:00',
#  'A665618-2013-10-21 16:04:00',
#  'A665623-2013-11-04 15:54:00',
#  'A665624-2014-03-04 10:06:00',
#  'A665627-2013-10-25 11:17:00',
#  'A665634-2013-11-18 16:05:00',
#  'A665635-2013-10-21 15:37:00',
#  'A665640-2013-10-20 18:00:00',
#  'A665641-2013-10-27 14:57:00',
#  'A665644-2013-10-21 11:39:00',
#  'A665645-2013-10-21 09:41:00',
#  'A665649-2013-10-21 10:44:00',
#  'A665651-2014-05-18 11:51:00',
#  'A665653-2013-10-23 17:30:00',
#  'A665654-2013-10-28 14:42:00',
#  'A665655-2013-10-23 17:30:00',
#  'A665656-2013-10-23 17:30:00',
#  'A665657-2013-10-23 17:29:00',
#  'A665659-2013-11-22 17:26:00',
#  'A665661-2013-12-26 09:31:00',
#  'A665661-2015-09-07 15:05:00',
#  'A665662-2014-01-01 10:50:00',
#  'A665666-2013-12-27 15:49:00',
#  'A665668-2014-03-19 08:37:00',
#  'A665671-2013-10-25 12:49:00',
#  'A665672-2013-11-03 11:40:00',
#  'A665673-2013-10-21 19:08:00',
#  'A665674-2013-11-03 17:27:00',
#  'A665676-2013-10-22 12:04:00',
#  'A665689-2013-10-27 14:37:00',
#  'A665711-2013-11-10 14:08:00',
#  'A665712-2013-10-23 15:08:00',
#  'A665712-2013-12-19 14:13:00',
#  'A665713-2013-10-23 15:07:00',
#  'A665713-2013-11-25 14:52:00',
#  'A665714-2013-10-23 15:07:00',
#  'A665714-2013-11-25 14:52:00',
#  'A665739-2013-12-20 17:36:00',
#  'A665740-2013-12-20 17:39:00',
#  'A665741-2013-10-24 15:44:00',
#  'A665741-2014-01-20 14:33:00',
#  'A665747-2013-10-24 15:55:00',
#  'A665753-2013-10-23 15:01:00',
#  'A665760-2013-10-26 15:54:00',
#  'A665784-2013-10-22 18:33:00',
#  'A665786-2013-10-22 18:32:00',
#  'A665795-2013-10-30 10:55:00',
#  'A665799-2013-11-01 19:24:00',
#  'A665800-2013-11-10 18:50:00',
#  'A665801-2013-11-09 17:11:00',
#  'A665802-2013-11-01 19:24:00',
#  'A665803-2013-11-10 18:50:00',
#  'A665804-2013-12-10 13:23:00',
#  'A665838-2013-10-24 15:25:00',
#  'A665842-2013-11-29 14:32:00',
#  'A665843-2013-11-03 16:41:00',
#  'A665853-2013-10-24 15:25:00',
#  'A665859-2013-10-24 15:24:00',
#  'A665871-2013-11-06 16:05:00',
#  'A665873-2013-11-05 16:16:00',
# ### Justification for removing duplicates:

# %% [markdown]
# Since each adoption was listed, animal id alone is not unique as shown by the analysis above.  In a few cases, the same animal was returned and adopted out again.  Adding outcome date helped with 1100 rows, but 7 rows were still duplicated.  The 7 duplicated entries are likely data entry errors (actual duplicate rows) and would have to be corrected before loading into a database table with this as a primary unique key.   Given this I will remove them by creating a new list that does not contain them.

# %% [markdown]
# ##### Create final list by only keeping 1 of each duplicated row.

# %%
# This runs through the old list of dictionaries and 
# only appends to the new one if there is no duplicated value
# or if it is the first entry found to have a duplicate value
dindex = 0
keptfirstlist = []
final_list = [] 
# Run through list 
while dindex < len(new_list):
    # Gather variables to check for duplicates
    for dictkey, dictval in new_list[dindex].items():
        if dictkey == "Animal ID":
            animal = dictval            
        if dictkey == "Outcome Age Timestamp":
            outcomedt = datetime.datetime.strptime(dictval, '%Y-%m-%d %H:%M:%S')
    newkey = animal + "-" + outcomedt.strftime("%Y-%m-%d %H:%M:%S")
    # Is it duplicated?
    if newkey in duplist:
        # Have we already created an entry for the duplicated row?
        if newkey in keptfirstlist:
            pass
        # If not create one and store it.
        else:
            keptfirstlist.append(newkey)
            final_list.append(new_list[dindex])
    # If not create row.
    else:
        final_list.append(new_list[dindex])
    dindex += 1

# %% [markdown]
# ##### Validate counts after duplicates are excluded.

# %%
# Compare list count with and with out duplicates
# Old list count - with duplicates
print("With duplicates:",len(new_list))
# Final list count - duplicate removed
print("Without duplicates:",len(final_list))
# Out:
# With duplicates: 29421
# Without duplicates: 29414

# %% [markdown]
# ### Conduct Fuzzy Matching
# ##### (if you don’t have an obvious example to do this with in your data, create categories and use Fuzzy Matching to lump data together)
# ### (Data Wrangling with Python pg. 179 – 188)

# %% [markdown]
# ##### IDA of colors

# %%
color_list = []

# %%
# Create a color list from the existing list of dictionarires
# Uses list comprehension 
# concept taken from https://www.geeksforgeeks.org/python-get-values-of-particular-key-in-list-of-dictionaries/
color_list = []
color_list = [ sub['Color'] for sub in final_list ]

# %%
# count of existing colors.
print(len(color_list))
# Out:
# 29414

# %%
# Gather unique colors
unqcolors, colorcount = np.unique(color_list, return_counts=True) 
# DEBUG - print(unqcolors)
# Convert to list for easier manipulation
unique_colors = unqcolors.tolist()

# %%
# Remove null values
unique_colors.remove("")
unique_colors.remove("/")
# Sort values
unique_colors.sort(key=len)

# %%
# Show all existing unique values
print(unique_colors)
# Out:
# ['tan', 'blue', 'buff', 'fawn', 'gray', 'lynx', 'pink', 'seal', '/blue', '/gray', '/lynx', 'black', 'blue/', 'brown', 'cream', 'flame', 'gray/', 'lilac', 'sable', 'white', '/black', '/brown', '/white', 'black/', 'lynx /', 'orange', 'silver', 'white/', 'yellow', '/orange', '/silver', 'apricot', 'brown /', 'gray/tan', 'orange /', 'blue /tan', 'blue/blue', 'blue/gray', 'chocolate', 'gray/gray', 'lynx /tan', 'tan/brown', 'tan/white', 'white/red', 'white/tan', 'black/blue', 'black/gray', 'black/seal', 'blue /buff', 'blue /gray', 'blue cream', 'blue/brown', 'blue/cream', 'blue/white', 'brown/buff', 'buff/white', 'cream/blue', 'cream/seal', 'gray/black', 'gray/white', 'lynx /blue', 'lynx /gray', 'seal /buff', 'seal /gray', 'white/blue', 'white/gray', 'white/lynx', 'white/seal', '/blue cream', 'black /gray', 'black/black', 'black/brown', 'black/white', 'blue /black', 'blue /cream', 'blue /white', 'blue cream/', 'blue/orange', 'brown /blue', 'brown /gray', 'brown merle', 'brown tiger', 'brown/black', 'brown/brown', 'brown/white', 'cream/brown', 'cream/white', 'gray /black', 'gray /white', 'lynx /brown', 'lynx /white', 'sable/white', 'seal /brown', 'seal /cream', 'seal /white', 'silver lynx', 'white/black', 'white/brown', 'white/cream', 'white/flame', 'white/lilac', 'white/white', 'black /black', 'black /brown', 'black /white', 'black/orange', 'black/silver', 'blue /orange', 'brown /black', 'brown /brown', 'brown /cream', 'brown /white', 'cream /cream', 'cream /white', 'cream/orange', 'flame /cream', 'flame /white', 'gray /orange', 'lilac /cream', 'lilac /white', 'orange tiger', 'orange/white', 'white/orange', 'white/silver', 'white/yellow', 'yellow/cream', 'black /orange', 'brown /orange', 'cream /orange', 'orange /black', 'orange /brown', 'orange /cream', 'orange /white', 'orange/orange', 'silver /black', 'silver /white', 'yellow/orange', 'orange /orange', 'black/chocolate', 'blue cream/blue', 'blue cream/buff', 'chocolate/black', 'chocolate/brown', 'chocolate/white', 'orange /apricot', 'white/chocolate', 'blue /blue cream', 'blue cream/white', 'chocolate /white', 'black tiger/white', 'brown merle/brown', 'brown tiger/white', 'silver lynx /gray']

# %%
# Number of unique colors
print("Unique color count before fuzzy logic:",len(unique_colors))
# Out:
# Unique color count before fuzzy logic: 153

# %% [markdown]
# ##### Fuzzy Example 1 - Match based on score of at least 96 to remove specific data entry concerns around color duplication.

# %%
# In this example I am focused on finding data entry issues resulting in duplicates 
# These could each be transformed into one value

firstrun_color = []
list_of_groupings = []
used_so_far = []
for colorquery in unique_colors:
    firstrun_color = []
    # DEBUG print (colorquery)
    for found, score in process.extract(colorquery, unique_colors, limit = 5):  
        # if "black" in colorquery:
            # print(colorquery,found,score)
        # From if statement used above 96 was determined to be the most effective value.
        if score > 95:
            if found not in used_so_far:
                firstrun_color.append(found)
                # Needed a way to take out of the list and avoid repeats
                used_so_far.append(found)
    firstrun_color.sort(key=len)        
    if firstrun_color not in list_of_groupings:
        if firstrun_color != []:
            list_of_groupings.append(firstrun_color)
list_of_groupings.sort()            
# pprint.pprint(list_of_groupings)       
# Colors that can be combined into one value due to data entry errors
print("\nThe values in red can be combined to correct data entry errors.\n")
for printlist in list_of_groupings:
    if len(printlist) > 1:
        print(colored(printlist,'red'))
    else:
        print(printlist)
# Out:
# The values in red can be combined to correct data entry errors.
#
# ['apricot']
# ['black', '/black', 'black/']
# ['black /gray']
# ['black tiger/white']
# ['black/black', 'black /black']
# ['black/blue']
# ['black/brown', 'black /brown']
# ['black/chocolate']
# ['black/gray']
# ['black/orange', 'black /orange']
# ['black/seal']
# ['black/silver']
# ['black/white', 'black /white']
# ['blue', '/blue', 'blue/']
# ['blue /black']
# ['blue /blue cream']
# ['blue /buff']
# ['blue /cream']
# ['blue /gray']
# ['blue /tan']
# ['blue /white']
# ['blue cream', 'blue/cream', '/blue cream', 'blue cream/']
# ['blue cream/blue']
# ['blue cream/buff']
# ['blue cream/white']
# ['blue/blue']
# ['blue/brown']
# ['blue/gray']
# ['blue/orange', 'blue /orange']
# ['blue/white']
# ['brown', '/brown', 'brown /']
# ['brown /blue']
# ['brown /cream']
# ['brown /gray']
# ['brown /orange']
# ['brown merle']
# ['brown merle/brown']
# ['brown tiger']
# ['brown tiger/white']
# ['brown/black', 'brown /black']
# ['brown/brown', 'brown /brown']
# ['brown/buff']
# ['brown/white', 'brown /white']
# ['buff']
# ['buff/white']
# ['chocolate']
# ['chocolate/black']
# ['chocolate/brown']
# ['chocolate/white', 'chocolate /white']
# ['cream']
# ['cream /cream']
# ['cream/blue']
# ['cream/brown']
# ['cream/orange', 'cream /orange']
# ['cream/seal']
# ['cream/white', 'cream /white']
# ['fawn']
# ['flame']
# ['flame /cream']
# ['flame /white']
# ['gray', '/gray', 'gray/']
# ['gray /black']
# ['gray /orange']
# ['gray /white']
# ['gray/black']
# ['gray/gray']
# ['gray/tan']
# ['gray/white']
# ['lilac']
# ['lilac /cream']
# ['lilac /white']
# ['lynx', '/lynx', 'lynx /']
# ['lynx /blue']
# ['lynx /brown']
# ['lynx /gray']
# ['lynx /tan']
# ['lynx /white']
# ['orange', '/orange', 'orange /']
# ['orange /apricot']
# ['orange /black']
# ['orange /brown']
# ['orange /cream']
# ['orange tiger']
# ['orange/orange', 'orange /orange']
# ['orange/white', 'orange /white']
# ['pink']
# ['sable']
# ['sable/white']
# ['seal']
# ['seal /brown']
# ['seal /buff']
# ['seal /cream']
# ['seal /gray']
# ['seal /white']
# ['silver', '/silver']
# ['silver /black']
# ['silver /white']
# ['silver lynx']
# ['silver lynx /gray']
# ['tan']
# ['tan/brown']
# ['tan/white']
# ['white', '/white', 'white/']
# ['white/black']
# ['white/blue']
# ['white/brown']
# ['white/chocolate']
# ['white/cream']
# ['white/flame']
# ['white/gray']
# ['white/lilac']
# ['white/lynx']
# ['white/orange']
# ['white/red']
# ['white/seal']
# ['white/silver']
# ['white/tan']
# ['white/white']
# ['white/yellow']
# ['yellow']
# ['yellow/cream']
# ['yellow/orange']

# %%
print("Potential count of groupings after removing duplicates due to data entry errors:",len(list_of_groupings))
# Out:
# Potential count of groupings after removing duplicates due to data entry errors: 122

# %% [markdown]
# ##### Fuzzy Example 2 - Fuzzy logic for color reduction by grouping like colors

# %%
#  In this example fuzzy logic is used to drastically reduce the number of 
#  color categories by grouping like lists which could possibly be merged.
#  It is not perfect as it partially relies on order, but given the messiness of the data
#  could be used to make a much cleaner reduction to a subjective set of data.

#  The goal in this cell is to reduce the color choices as much as possible to reduce subjectivity 
#  while keeping some level of integrity from the answers provided thus showing the potential of fuzzy logic.

firstrun_color = []
list_of_groupings = []
used_so_far = []
for colorquery in unique_colors:
    firstrun_color = []
    # Gather top 35 matches
    for found, score in process.extract(colorquery, unique_colors, scorer=fuzz.token_set_ratio, limit = 35):      
        # Only consider scores over 75
        if score > 75:
            if found not in used_so_far:
                firstrun_color.append(found)
                # Needed a way to take out of the list and avoid repeats
                used_so_far.append(found)
    firstrun_color.sort()        
    if firstrun_color not in list_of_groupings:
        if firstrun_color != []:
            list_of_groupings.append(firstrun_color)
list_of_groupings.sort()
counter=0
print ("\nPotential new color groupings:")
for collist in list_of_groupings:
    # Add new line for easier reading of distinct new list of combined colors
    print("\n", collist)
    counter += 1
# Out:
# Potential new color groupings:
#
#  ['/black', 'black', 'black /black', 'black /brown', 'black /orange', 'black /white', 'black tiger/white', 'black/', 'black/black', 'black/brown', 'black/chocolate', 'black/orange', 'black/silver', 'black/white', 'brown /black', 'brown/black', 'chocolate/black', 'orange /black', 'silver /black', 'white/black']
#
#  ['/blue', '/blue cream', 'black/blue', 'blue', 'blue /black', 'blue /blue cream', 'blue /buff', 'blue /cream', 'blue /gray', 'blue /orange', 'blue /white', 'blue cream', 'blue cream/', 'blue cream/blue', 'blue cream/buff', 'blue cream/white', 'blue/', 'blue/blue', 'blue/brown', 'blue/cream', 'blue/gray', 'blue/orange', 'blue/white', 'brown /blue', 'cream/blue', 'lynx /blue', 'white/blue']
#
#  ['/brown', 'brown', 'brown /', 'brown /brown', 'brown /cream', 'brown /orange', 'brown /white', 'brown merle', 'brown merle/brown', 'brown tiger', 'brown tiger/white', 'brown/brown', 'brown/white', 'chocolate/brown', 'cream/brown', 'orange /brown', 'white/brown']
#
#  ['/gray', 'black /gray', 'black/gray', 'brown /gray', 'gray', 'gray /black', 'gray /orange', 'gray /white', 'gray/', 'gray/black', 'gray/gray', 'gray/white', 'lynx /gray', 'seal /gray', 'silver lynx /gray', 'white/gray']
#
#  ['/lynx', 'lynx', 'lynx /', 'lynx /brown', 'lynx /white', 'silver lynx', 'white/lynx']
#
#  ['/orange', 'orange', 'orange /', 'orange /apricot', 'orange /orange', 'orange /white', 'orange tiger', 'orange/orange', 'yellow/orange']
#
#  ['/silver', 'silver', 'silver /white']
#
#  ['/white', 'orange/white', 'white', 'white/', 'white/orange', 'white/red', 'white/silver', 'white/white']
#
#  ['apricot']
#
#  ['black/seal', 'cream/seal', 'seal', 'seal /brown', 'seal /cream', 'seal /white', 'white/seal']
#
#  ['blue /tan', 'gray/tan', 'lynx /tan', 'tan', 'tan/brown', 'tan/white', 'white/tan']
#
#  ['brown/buff', 'buff', 'buff/white', 'seal /buff']
#
#  ['chocolate', 'chocolate /white', 'chocolate/white', 'white/chocolate']
#
#  ['cream', 'cream /cream', 'cream /orange', 'cream /white', 'cream/orange', 'cream/white', 'flame /cream', 'lilac /cream', 'orange /cream', 'white/cream', 'yellow/cream']
#
#  ['fawn']
#
#  ['flame', 'flame /white', 'white/flame']
#
#  ['lilac', 'lilac /white', 'white/lilac']
#
#  ['pink']
#
#  ['sable', 'sable/white']
#
#  ['white/yellow', 'yellow']

# %%
print("New count of groupings after using fuzzy logic to combine colors:",len(list_of_groupings))
# Out:
# New count of groupings after using fuzzy logic to combine colors: 20
